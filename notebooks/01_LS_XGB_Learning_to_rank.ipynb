# %% [markdown]
# ### Learning to rank with XGB - basic example
#
# - based on small subset
# - amenities not merged
# - only left integer/float variables, no feature pre-processing

# %% [markdown]
# code folllows this example https://www.kaggle.com/code/azimuthal01/learning-to-rank

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/expedia/exploded_df.csv")

# %%
df.head()
# Out:
#                             user_id                         search_id  \
# 0  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 1  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 2  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 3  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 4  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
#
#            search_timestamp  point_of_sale  geo_location_country  is_mobile  \
# 0  2021-07-02T19:38:00.000Z              2                     1          0
# 1  2021-07-02T19:38:00.000Z              2                     1          0
# 2  2021-07-02T19:38:00.000Z              2                     1          0
# 3  2021-07-02T19:38:00.000Z              2                     1          0
# 4  2021-07-02T19:38:00.000Z              2                     1          0
#
#    destination_id checkin_date checkout_date  adult_count  ...  review_rating  \
# 0             898   2021-07-04    2021-07-05            2  ...            4.0
# 1             898   2021-07-04    2021-07-05            2  ...            4.0
# 2             898   2021-07-04    2021-07-05            2  ...            5.0
# 3             898   2021-07-04    2021-07-05            2  ...            4.0
# 4             898   2021-07-04    2021-07-05            2  ...            4.0
#
#    review_count  star_rating is_free_cancellation is_drr  price_bucket  \
# 0         250.0          2.0                    1      0           3.0
# 1        1000.0          2.0                    1      0           4.0
# 2         700.0          3.0                    1      0           3.0
# 3         250.0          2.0                    1      0           3.0
# 4         625.0          2.0                    0      0           1.0
#
#    num_clicks  is_trans  qid  relevance
# 0           0         0    1          0
# 1           0         0    1          0
# 2           0         0    1          0
# 3           0         0    1          0
# 4           0         0    1          0
#
# [5 rows x 28 columns]

# %%
# create integer query ID

group_map = {}
counter = 1
for group in df['search_id'].unique():
    group_map[group] = counter
    counter += 1

# Apply the mapping to create a new column with integer identifiers
df['qid'] = df['search_id'].map(group_map)

df.head()
# Out:
#                             user_id                         search_id  \
# 0  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 1  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 2  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 3  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 4  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
#
#            search_timestamp  point_of_sale  geo_location_country  is_mobile  \
# 0  2021-07-02T19:38:00.000Z              2                     1          0
# 1  2021-07-02T19:38:00.000Z              2                     1          0
# 2  2021-07-02T19:38:00.000Z              2                     1          0
# 3  2021-07-02T19:38:00.000Z              2                     1          0
# 4  2021-07-02T19:38:00.000Z              2                     1          0
#
#    destination_id checkin_date checkout_date  adult_count  ...  is_travel_ad  \
# 0             898   2021-07-04    2021-07-05            2  ...             1
# 1             898   2021-07-04    2021-07-05            2  ...             1
# 2             898   2021-07-04    2021-07-05            2  ...             0
# 3             898   2021-07-04    2021-07-05            2  ...             0
# 4             898   2021-07-04    2021-07-05            2  ...             0
#
#    review_rating  review_count star_rating is_free_cancellation  is_drr  \
# 0            4.0         250.0         2.0                    1       0
# 1            4.0        1000.0         2.0                    1       0
# 2            5.0         700.0         3.0                    1       0
# 3            4.0         250.0         2.0                    1       0
# 4            4.0         625.0         2.0                    0       0
#
#    price_bucket  num_clicks  is_trans  qid
# 0           3.0           0         0    1
# 1           4.0           0         0    1
# 2           3.0           0         0    1
# 3           3.0           0         0    1
# 4           1.0           0         0    1
#
# [5 rows x 27 columns]

# %%
### create relevance label
# 1 for clicked on
# 2 for transaction

df['relevance'] = 0  # Initialize with default value
df.loc[df['num_clicks'] > 0, 'relevance'] = 1  # Set value to 1 if first_column > 0
df.loc[df['is_trans'] > 0, 'relevance'] += 2  # Add 2 if second_column > 0

df.head(10)
# Out:
#                             user_id                         search_id  \
# 0  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 1  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 2  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 3  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 4  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 5  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 6  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 7  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 8  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 9  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
#
#            search_timestamp  point_of_sale  geo_location_country  is_mobile  \
# 0  2021-07-02T19:38:00.000Z              2                     1          0
# 1  2021-07-02T19:38:00.000Z              2                     1          0
# 2  2021-07-02T19:38:00.000Z              2                     1          0
# 3  2021-07-02T19:38:00.000Z              2                     1          0
# 4  2021-07-02T19:38:00.000Z              2                     1          0
# 5  2021-07-02T19:38:00.000Z              2                     1          0
# 6  2021-07-02T19:38:00.000Z              2                     1          0
# 7  2021-07-02T19:38:00.000Z              2                     1          0
# 8  2021-07-02T19:38:00.000Z              2                     1          0
# 9  2021-07-02T19:38:00.000Z              2                     1          0
#
#    destination_id checkin_date checkout_date  adult_count  ...  review_rating  \
# 0             898   2021-07-04    2021-07-05            2  ...            4.0
# 1             898   2021-07-04    2021-07-05            2  ...            4.0
# 2             898   2021-07-04    2021-07-05            2  ...            5.0
# 3             898   2021-07-04    2021-07-05            2  ...            4.0
# 4             898   2021-07-04    2021-07-05            2  ...            4.0
# 5             898   2021-07-04    2021-07-05            2  ...            5.0
# 6             898   2021-07-04    2021-07-05            2  ...            4.0
# 7             898   2021-07-04    2021-07-05            2  ...            4.0
# 8             898   2021-07-04    2021-07-05            2  ...            4.0
# 9             898   2021-07-04    2021-07-05            2  ...            4.0
#
#    review_count  star_rating is_free_cancellation is_drr  price_bucket  \
# 0         250.0          2.0                    1      0           3.0
# 1        1000.0          2.0                    1      0           4.0
# 2         700.0          3.0                    1      0           3.0
# 3         250.0          2.0                    1      0           3.0
# 4         625.0          2.0                    0      0           1.0
# 5         525.0          3.0                    1      0           5.0
# 6          75.0          3.0                    1      1           2.0
# 7        1000.0          2.0                    1      0           4.0
# 8         250.0          3.0                    1      0           2.0
# 9         575.0          2.0                    1      1           4.0
#
#    num_clicks  is_trans  qid  relevance
# 0           0         0    1          0
# 1           0         0    1          0
# 2           0         0    1          0
# 3           0         0    1          0
# 4           0         0    1          0
# 5           0         0    1          0
# 6           1         0    1          1
# 7           0         0    1          0
# 8           1         0    1          1
# 9           0         0    1          0
#
# [10 rows x 28 columns]

# %%
df.relevance.mean()
# Out:
# 0.010812402709411419

# %%
## keep only integer/float columns for XGB

df_model = df.drop(labels = ["user_id", "search_id", "search_timestamp",
                             "checkin_date", "checkout_date", "num_clicks",
                             "is_trans", "sort_type", "applied_filters", "rank"],
                    axis=1)

# if i exclude the initial rank from the data - do i ignore the potential effect
#  on relevance (clicks) the initial ranking has on the relevance proxies?

df_model.head()
# Out:
#    point_of_sale  geo_location_country  is_mobile  destination_id  \
# 0              2                     1          0             898
# 1              2                     1          0             898
# 2              2                     1          0             898
# 3              2                     1          0             898
# 4              2                     1          0             898
#
#    adult_count  child_count  infant_count  room_count  prop_id  is_travel_ad  \
# 0            2            0             0           1  5695234             1
# 1            2            0             0           1  1734546             1
# 2            2            0             0           1  5675938             0
# 3            2            0             0           1  5695234             0
# 4            2            0             0           1  2012023             0
#
#    review_rating  review_count  star_rating  is_free_cancellation  is_drr  \
# 0            4.0         250.0          2.0                     1       0
# 1            4.0        1000.0          2.0                     1       0
# 2            5.0         700.0          3.0                     1       0
# 3            4.0         250.0          2.0                     1       0
# 4            4.0         625.0          2.0                     0       0
#
#    price_bucket  qid  relevance
# 0           3.0    1          0
# 1           4.0    1          0
# 2           3.0    1          0
# 3           3.0    1          0
# 4           1.0    1          0

# %%
df_model.shape
# Out:
# (71307, 18)

# %%
# separate train and test by qid, so same queries stay together

train_df = df_model[df_model["qid"] >= 200]
train_df.shape
# Out:
# (55480, 18)

# %%
test_df = train_df = df_model[df_model["qid"] < 200]
test_df.shape
# Out:
# (15827, 18)

# %%
X = train_df[train_df.columns[0:16]]
y = train_df["relevance"]

# %%
X.head()
# Out:
#    point_of_sale  geo_location_country  is_mobile  destination_id  \
# 0              2                     1          0             898
# 1              2                     1          0             898
# 2              2                     1          0             898
# 3              2                     1          0             898
# 4              2                     1          0             898
#
#    adult_count  child_count  infant_count  room_count  prop_id  is_travel_ad  \
# 0            2            0             0           1  5695234             1
# 1            2            0             0           1  1734546             1
# 2            2            0             0           1  5675938             0
# 3            2            0             0           1  5695234             0
# 4            2            0             0           1  2012023             0
#
#    review_rating  review_count  star_rating  is_free_cancellation  is_drr  \
# 0            4.0         250.0          2.0                     1       0
# 1            4.0        1000.0          2.0                     1       0
# 2            5.0         700.0          3.0                     1       0
# 3            4.0         250.0          2.0                     1       0
# 4            4.0         625.0          2.0                     0       0
#
#    price_bucket
# 0           3.0
# 1           4.0
# 2           3.0
# 3           3.0
# 4           1.0

# %%
X_test = test_df[train_df.columns[0:16]]
y_test = test_df["relevance"]

# %%
g = train_df.groupby(by="qid")
size = g.size()
group_train = size.to_list()

g = test_df.groupby(by="qid")
size = g.size()
group_valid = size.to_list()

# %%
import xgboost as xgb

# %%
ranker = xgb.XGBRanker(
        n_estimators=100,
        learning_rate=0.1,
        objective='rank:ndcg',
        reg_lambda=0.05,
        # verbose = True,
        tree_method = 'gpu_hist'
    )

ranker.fit(
    X.astype(float),
    y.astype(int),
    group=group_train,
    eval_group=[group_valid],
    eval_set=[(X_test.astype(float), y_test.astype(int))],
    early_stopping_rounds=100,
    verbose = True
)
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [13:10:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# [0]	validation_0-ndcg@32:0.91034
# [1]	validation_0-ndcg@32:0.92574
# [2]	validation_0-ndcg@32:0.93421
# [3]	validation_0-ndcg@32:0.94623
# [4]	validation_0-ndcg@32:0.95040
# [5]	validation_0-ndcg@32:0.95596
# [6]	validation_0-ndcg@32:0.95542
# [7]	validation_0-ndcg@32:0.95431
# [8]	validation_0-ndcg@32:0.95903
# [9]	validation_0-ndcg@32:0.96669
# [10]	validation_0-ndcg@32:0.96828
# [11]	validation_0-ndcg@32:0.96894
# [12]	validation_0-ndcg@32:0.97006
# [13]	validation_0-ndcg@32:0.97122
# [14]	validation_0-ndcg@32:0.97146
# [15]	validation_0-ndcg@32:0.97183
# [16]	validation_0-ndcg@32:0.97162
# [17]	validation_0-ndcg@32:0.97265
# [18]	validation_0-ndcg@32:0.97465
# [19]	validation_0-ndcg@32:0.97480
# [20]	validation_0-ndcg@32:0.97638
# [21]	validation_0-ndcg@32:0.97636
# [22]	validation_0-ndcg@32:0.97766
# [23]	validation_0-ndcg@32:0.97752
# [24]	validation_0-ndcg@32:0.97800
# [25]	validation_0-ndcg@32:0.97989
# [26]	validation_0-ndcg@32:0.97998
# [27]	validation_0-ndcg@32:0.98004
# [28]	validation_0-ndcg@32:0.98022
# [29]	validation_0-ndcg@32:0.98045
# [30]	validation_0-ndcg@32:0.97992
# [31]	validation_0-ndcg@32:0.98002
# [32]	validation_0-ndcg@32:0.98042
# [33]	validation_0-ndcg@32:0.98492
# [34]	validation_0-ndcg@32:0.98500
# [35]	validation_0-ndcg@32:0.98500
# [36]	validation_0-ndcg@32:0.98582
# [37]	validation_0-ndcg@32:0.98609
# [38]	validation_0-ndcg@32:0.98613
# [39]	validation_0-ndcg@32:0.98615
# [40]	validation_0-ndcg@32:0.98616
# [41]	validation_0-ndcg@32:0.98622
# [42]	validation_0-ndcg@32:0.98666
# [43]	validation_0-ndcg@32:0.98780
# [44]	validation_0-ndcg@32:0.98780
# [45]	validation_0-ndcg@32:0.98779
# [46]	validation_0-ndcg@32:0.98779
# [47]	validation_0-ndcg@32:0.98841
# [48]	validation_0-ndcg@32:0.98887
# [49]	validation_0-ndcg@32:0.98887
# [50]	validation_0-ndcg@32:0.98884
# [51]	validation_0-ndcg@32:0.98917
# [52]	validation_0-ndcg@32:0.98917
# [53]	validation_0-ndcg@32:0.98917
# [54]	validation_0-ndcg@32:0.98920
# [55]	validation_0-ndcg@32:0.99012
# [56]	validation_0-ndcg@32:0.99017
# [57]	validation_0-ndcg@32:0.99018
# [58]	validation_0-ndcg@32:0.99019
# [59]	validation_0-ndcg@32:0.99020
# [60]	validation_0-ndcg@32:0.99022
# [61]	validation_0-ndcg@32:0.99022
# [62]	validation_0-ndcg@32:0.99088
# [63]	validation_0-ndcg@32:0.99088
# [64]	validation_0-ndcg@32:0.99094
# [65]	validation_0-ndcg@32:0.99100
# [66]	validation_0-ndcg@32:0.99103
# [67]	validation_0-ndcg@32:0.99109
# [68]	validation_0-ndcg@32:0.99111
# [69]	validation_0-ndcg@32:0.99113
# [70]	validation_0-ndcg@32:0.99116
# [71]	validation_0-ndcg@32:0.99116
# [72]	validation_0-ndcg@32:0.99122
# [73]	validation_0-ndcg@32:0.99122
# [74]	validation_0-ndcg@32:0.99122
# [75]	validation_0-ndcg@32:0.99122
# [76]	validation_0-ndcg@32:0.99122
# [77]	validation_0-ndcg@32:0.99126
# [78]	validation_0-ndcg@32:0.99146
# [79]	validation_0-ndcg@32:0.99169
# [80]	validation_0-ndcg@32:0.99229
# [81]	validation_0-ndcg@32:0.99229
# [82]	validation_0-ndcg@32:0.99415
# [83]	validation_0-ndcg@32:0.99415
# [84]	validation_0-ndcg@32:0.99455
# [85]	validation_0-ndcg@32:0.99469
# [86]	validation_0-ndcg@32:0.99469
# [87]	validation_0-ndcg@32:0.99469
# [88]	validation_0-ndcg@32:0.99469
# [89]	validation_0-ndcg@32:0.99469
# [90]	validation_0-ndcg@32:0.99469
# [91]	validation_0-ndcg@32:0.99469
# [92]	validation_0-ndcg@32:0.99474
# [93]	validation_0-ndcg@32:0.99474
# [94]	validation_0-ndcg@32:0.99474
# [95]	validation_0-ndcg@32:0.99480
# [96]	validation_0-ndcg@32:0.99480
# [97]	validation_0-ndcg@32:0.99480
# [98]	validation_0-ndcg@32:0.99480
# [99]	validation_0-ndcg@32:0.99480
# XGBRanker(base_score=None, booster=None, callbacks=None, colsample_bylevel=None,
#           colsample_bynode=None, colsample_bytree=None, device=None,
#           early_stopping_rounds=None, enable_categorical=False,
#           eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#           importance_type=None, interaction_constraints=None, learning_rate=0.1,
#           max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#           max_delta_step=None, max_depth=None, max_leaves=None,
#           min_child_weight=None, missing=nan, monotone_constraints=None,
#           multi_strategy=None, n_estimators=100, n_jobs=None,
#           num_parallel_tree=None, random_state=None, ...)

# %%
test_pred = ranker.predict(X_test.astype(float))
y_test_df = pd.DataFrame({"relevance_score": y_test, "predicted_ranking": test_pred})
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [13:11:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [13:11:16] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)

# %%
true_relevance = y_test.sort_values(ascending=False)
relevance_score = y_test_df.sort_values("predicted_ranking", ascending=False)

# %%
import numpy as np
from sklearn.metrics import ndcg_score

# %%
print(
        "nDCG score: ",
        ndcg_score(
            [true_relevance.to_numpy()], [relevance_score["relevance_score"].to_numpy()]
        ),
    )

print(
        "nDCG score @ 5: ",
        ndcg_score(
            y_true = [true_relevance.to_numpy()], y_score = [relevance_score["relevance_score"].to_numpy()], k=5
        ),
    )

print(
        "nDCG score @ 10: ",
        ndcg_score(
            y_true = [true_relevance.to_numpy()], y_score = [relevance_score["relevance_score"].to_numpy()], k=10
        ),
    )

print(
        "nDCG score @ 50: ",
        ndcg_score(
            y_true = [true_relevance.to_numpy()], y_score = [relevance_score["relevance_score"].to_numpy()], k=50
        ),
    )
# Out:
# nDCG score:  0.6098304701119245
# nDCG score @ 5:  0.3485784195172989
# nDCG score @ 10:  0.375954803951898
# nDCG score @ 50:  0.44183947328436
