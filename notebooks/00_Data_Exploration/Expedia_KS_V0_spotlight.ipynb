# %%
import pandas as pd
import gzip

def read_expedia_gzip_data(file_path):
    """
    Read a .tsv.gz compressed dataset file into a pandas DataFrame.

    Parameters:
    file_path (str): The file path to the .tsv.gz file.

    Returns:
    pd.DataFrame: A DataFrame containing the data from the .tsv.gz file.
    """
    # Use gzip.open to read the gzipped file in binary mode ('rb'), then parse it with pandas
    with gzip.open(file_path, 'rb') as file:
        df = pd.read_csv(file, sep='\t')

    return df

# %%
import gzip
import shutil

def write_to_gzipfile(tsv_filename, tsv_gz_filename):
    with open(tsv_filename, 'rb') as f_in:
        with gzip.open(tsv_gz_filename, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)

# %%
import pandas as pd
import os

gz_tsv_dir_path = os.path.dirname(os.path.realpath(__file__))
gz_file_extension = '.gz'
tsv_filename = 'main.tsv'
tsv_gz_filename = tsv_filename + gz_file_extension; 
tsv_gz_file_path = gz_tsv_dir_path + '/' + tsv_gz_filename;

df = read_expedia_gzip_data(tsv_gz_file_path)

# get subset from the dataframe
subset = df.loc[:20000];

tsv_sample_filename = 'subset_sample.tsv';

# convert to tsv file
subset.to_csv(tsv_sample_filename, sep="\t")

tsv_gz_sample_filename = tsv_filename + gz_file_extension;

write_to_gzipfile(tsv_sample_filename, tsv_gz_sample_filename)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 df_amenities = pd.read_csv("https://drive.google.com/file/d/1mPBrNNW18roMUsmym66di8F1FJIt5pom", compression='gzip', sep='\t')
#       3 df_main = pd.read_csv("https://drive.google.com/file/d/1iCjnM-LTHsd3Vu8e58ANRnSKOXe08pK2", compression='gzip', sep='\t')
#
# ...

# %%
# Display the DataFrame
df_main.head()
# Out:
#                             user_id                         search_id  \
# 0  001bbff3030c95740d4c55bb72e823e9  541933a931216d270f53277c2de068d0
# 1  002ba2a7c74dbffc32e4568af230d49a  25b8ebecb15b8f3edb5eed36a1f699b4
# 2  00c5152ed6ef5b937e8320a260bde084  349c86ff1be41553878e01988ca209d1
# 3  00d5e2bca7962f67d5695e7e7b92feb8  d3b41f5d906b3f5e56bcafd4a7428634
# 4  013f92616fe583c4ba0c3919b69cf3d9  a359fd984e5ae5be64af5226dd1e9fe2
#
#            search_timestamp  point_of_sale  geo_location_country  is_mobile  \
# 0  2021-07-02T19:38:00.000Z              2                     1          0
# 1  2021-06-23T03:39:00.000Z              1                     1          0
# 2  2021-06-10T00:08:00.000Z              1                     1          0
# 3  2021-07-16T01:08:00.000Z             12                     1          0
# 4  2021-07-07T20:49:00.000Z              1                     1          0
#
#    destination_id checkin_date checkout_date  adult_count  child_count  \
# ...

# %%
df_main[df_main['applied_filters'].notna()].head()
# Out:
#                              user_id                         search_id  \
# 4   013f92616fe583c4ba0c3919b69cf3d9  a359fd984e5ae5be64af5226dd1e9fe2
# 5   0152236295041a611d45ed97353d73df  cc8875772f124695111939cc8c08e59a
# 14  018e7d1f2484459af14daf74d8aabb95  dd89d215b0a608de71666da440e3fdcc
# 16  022618a80fb6c8614855c66204e0e03b  daabcde78180d12e2f99dc933ae43e3c
# 17  023fc9d701c799c627bb9fc68fa55816  197e29f822ed8ef83b9d339b892ced5e
#
#             search_timestamp  point_of_sale  geo_location_country  is_mobile  \
# 4   2021-07-07T20:49:00.000Z              1                     1          0
# 5   2021-06-10T14:49:00.000Z              2                     1          1
# 14  2021-06-18T21:20:00.000Z              6                     4          0
# 16  2021-06-28T13:29:00.000Z             11                     4          0
# 17  2021-06-19T02:20:00.000Z              3                     2          0
#
#     destination_id checkin_date checkout_date  adult_count  child_count  \
# ...

# %%
df_main.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_main.dtypes
#
# NameError: name 'df_main' is not defined

# %% [markdown]
# Quantifying ranking success with NDCG

# %%
def dcg(relevances, rank=10):
    """Discounted cumulative gain at rank (DCG)"""
    relevances = np.asarray(relevances)[:rank]
    n_relevances = len(relevances)
    if n_relevances == 0:
        return 0.

    discounts = np.log2(np.arange(n_relevances) + 2)
    return np.sum(relevances / discounts)
 
 
def ndcg(relevances, rank=10):
    """Normalized discounted cumulative gain (NDGC)"""
    best_dcg = dcg(sorted(relevances, reverse=True), rank)
    if best_dcg == 0:
        return 0.

    return dcg(relevances, rank) / best_dcg
